# %% [markdown]
# # General Understanding of Feature Engineering

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2011.40.29%20AM.png](attachment:Screenshot%202023-10-31%20at%2011.40.29%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2011.41.40%20AM.png](attachment:Screenshot%202023-10-31%20at%2011.41.40%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2011.37.29%20AM.png](attachment:Screenshot%202023-10-31%20at%2011.37.29%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2011.49.48%20AM.png](attachment:Screenshot%202023-10-31%20at%2011.49.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2011.51.28%20AM.png](attachment:Screenshot%202023-10-31%20at%2011.51.28%20AM.png)

# %% [markdown]
# ## Categorical Encoding

# %% [markdown]
# ### Label Encoding

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2011.54.19%20AM.png](attachment:Screenshot%202023-10-31%20at%2011.54.19%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2011.55.29%20AM.png](attachment:Screenshot%202023-10-31%20at%2011.55.29%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2011.56.44%20AM.png](attachment:Screenshot%202023-10-31%20at%2011.56.44%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2011.58.56%20AM.png](attachment:Screenshot%202023-10-31%20at%2011.58.56%20AM.png)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# Create a sample dataset
data = {'Size': ['Small', 'Medium', 'Large', 'Small', 'Large']}
df = pd.DataFrame(data)

# %%
# Initialize the LabelEncoder
encoder = LabelEncoder()
# Apply label encoding to the ’Size’column
df['Encoded Size'] = encoder.fit_transform(df['Size'])
# Display the encoded dataset
print(df)
# Out:
#      Size  Encoded Size
# 0   Small             2
# 1  Medium             1
# 2   Large             0
# 3   Small             2
# 4   Large             0

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2012.03.30%20PM.png](attachment:Screenshot%202023-10-31%20at%2012.03.30%20PM.png)

# %% [markdown]
# ## One Hot Encoding

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2012.06.47%20PM.png](attachment:Screenshot%202023-10-31%20at%2012.06.47%20PM.png)

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2012.08.08%20PM.png](attachment:Screenshot%202023-10-31%20at%2012.08.08%20PM.png)

# %%
### To perform one-hot encoding in Python, you can use the getdummies function from the pandas library:
import pandas as pd
# Create a sample dataset
data = {'Animal': ['Dog', 'Cat', 'Elephant', 'Dog', 'Elephant']}
df = pd.DataFrame(data)
# Apply one-hot encoding to the ’Animal’ column
encoded_df = pd.get_dummies(df, columns=['Animal'])
# Display the encoded dataset
print(encoded_df)
# Out:
#    Animal_Cat  Animal_Dog  Animal_Elephant
# 0           0           1                0
# 1           1           0                0
# 2           0           0                1
# 3           0           1                0
# 4           0           0                1

# %% [markdown]
# ![Screenshot%202023-10-31%20at%2012.11.22%20PM.png](attachment:Screenshot%202023-10-31%20at%2012.11.22%20PM.png)
